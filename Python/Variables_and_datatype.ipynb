# %%
my_fav_color="blue"
my_fav_color
# Out:
# 'blue'

# %%
color1,color2,color3="red","green","blue"

# %%
color1
# Out:
# 'red'

# %%
color2
# Out:
# 'green'

# %%
color3==my_fav_color
# Out:
# True

# %%
color4=color5=color6="Magenta"

# %%
color4
# Out:
# 'Magenta'

# %%
color5
# Out:
# 'Magenta'

# %%
color6
# Out:
# 'Magenta'

# %%
my_fav_color="red"
my_fav_color
# Out:
# 'red'

# %%
my_fav_color==color3
# Out:
# False

# %%
counter=10
counter+=4

# %%
counter
# Out:
# 14

# %%
counter-=10
counter
# Out:
# 4

# %% [markdown]
# Variables name can be short (a,x,y etc) pr descriptive (my_favorite_color,profit_margin,the_3_musketeers etc). However , you must follow these rules while naming Python variables

# %%
a_variable =40
is_today_monday=False
my_favourite_car="Buccarti"
the_3_musketeers=["Athos","Porthos","Aramis"]

# %%
a_variable
# Out:
# 40

# %%
type(a_variable)
# Out:
# int

# %%
is_today_monday
# Out:
# False

# %%
type(is_today_monday)
# Out:
# bool

# %%
my_favourite_car
# Out:
# 'Buccarti'

# %%
type(my_favourite_car)
# Out:
# str

# %%
the_3_musketeers
# Out:
# ['Athos', 'Porthos', 'Aramis']

# %%
type(the_3_musketeers)
# Out:
# list

# %% [markdown]
# ### Python has several built in data types for storing different types of information in variables . Following are at some commonly used data types:
# 1) Integer
# 2) Float
# 3) Boolean
# 4) None
# 5) String
# 6) List
# 7) Tuple
#
# 1,2,3 are primitive data types because they represent a single value and other likes list,tuple and dictionary are often called data structures or containers because they hold multiple pieces of data together.

# %%
number = 3.0

# %%
type(number)
# Out:
# float

# %%
number_a=4.
type(number_a)
# Out:
# float

# %%
one_hundredth=1e-2
one_hundredth
# Out:
# 0.01

# %%
type(one_hundredth)
# Out:
# float

# %%
avogadro_number= 6.024e-23
avogadro_number
# Out:
# 6.024e-23

# %%
pi = 3.141234
pi
# Out:
# 3.141234

# %%
a=int(pi)
a
# Out:
# 3

# %%
type(a)
# Out:
# int

# %% [markdown]
# Boolean are automatically converted to int s when used in arithmetic operations. True is converted to 1 and False is converted to 0.

# %%
5 + False
# Out:
# 5

# %%
5 + True
# Out:
# 6

# %% [markdown]
# # Boolean Example
# for False

# %%
bool(0)
# Out:
# False

# %%
bool(())
# Out:
# False

# %%
bool({})
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool("")
# Out:
# False

# %%
bool(True),bool(1),bool(2.0),bool("hello"),bool([1,2]),bool((2,3))
# Out:
# (True, True, True, True, True, True)

# %% [markdown]
# ## None
# The None type includes a single value NOne, used to indicate the absence of a value.None has the type NoneType. It is often used to declare a variable whose value may be assigned later.

# %%
nothing=None
type(nothing)
# Out:
# NoneType

# %% [markdown]
# ## String
# A string is used to text in python. Strings must be sdurrounded using quotations . Strings have the type str.

# %%
today="Saturday"
today
# Out:
# 'Saturday'

# %%
type(today)
# Out:
# str

# %% [markdown]
# You can use single quotes inside a string written with double quotes, and vice versa.

# %%
my_favorite_movie='One Flew over the Cuckoo\'s Nest'
my_favorite_movie
# Out:
# "One Flew over the Cuckoo's Nest"

# %%
my_favorite_song=""""arithmetic operation.ipynb"Hare Krishna Hare Krishna \" Krishna Krishna \''' Krishna Hare Hare '''-- Hare Rama Hare Rama Rama Rama Hare Hare"""

# %%
my_favorite_song
# Out:
# '"arithmetic operation.ipynb"Hare Krishna Hare Krishna " Krishna Krishna \'\'\' Krishna Hare Hare \'\'\'-- Hare Rama Hare Rama Rama Rama Hare Hare'

# %%
a_music_pun=""" 
Two windmills are standing in a field and one asks the other,
"What Kind of music do you like? " 

The other says,
"I'm a big metal fan." """

# %%
a_music_pun
# Out:
# ' \nTwo windmills are standing in a field and one asks the other,\n"What Kind of music do you like? " \n\nThe other says,\n"I\'m a big metal fan." '

# %%
len(a_music_pun)
# Out:
# 140

# %%
multiline_string="""a 
b"""
multiline_string
# Out:
# 'a \nb'

# %%
len(multiline_string)
# Out:
# 4

# %%
list(multiline_string)
# Out:
# ['a', ' ', '\n', 'b']

# %%
today="saturday"
today
# Out:
# 'saturday'

# %%
today[1]
# Out:
# 'a'

# %%
today[6]
# Out:
# 'a'

# %%
today[1:5]
# Out:
# 'atur'

# %%
"day"in today
# Out:
# True

# %%
"atur" in today
# Out:
# True

# %%
"ad" in today
# Out:
# False

# %%
full_name="Shree Krishna"
greeting="Hello"
greeting+" "+ full_name + "!"
# Out:
# 'Hello Shree Krishna!'

# %%
today.upper()
# Out:
# 'SATURDAY'

# %%
today.lower()
# Out:
# 'saturday'

# %%
"Roshan".upper()
# Out:
# 'ROSHAN'

# %%
"dipesh".capitalize()
# Out:
# 'Dipesh'

# %% [markdown]
# The .replace method is used to replace a part of the string with another string. It takes the portion to be replaced and the replacement text as inputs or arguments.

# %%
another_day=today.replace("satur","Wednes")

# %%
another_day
# Out:
# 'Wednesday'

# %%
today
# Out:
# 'saturday'

# %% [markdown]
# The .plit method can be used to split a string int oa list of strings based using the character(s) provided

# %%
# Split Method
"Sun,Mon,Tue,Wed,Thu,Fri,Sat".split(",")
# Out:
# ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']

# %% [markdown]
# The .strip method is used remove whitespace characters from the beginning and end of a string.

# %%
a_long_line="    This is a long line with some space before , after,            "
a_long_line_stripped=a_long_line.strip()
a_long_line_stripped
# Out:
# 'This is a long line with some space before , after,'

# %%
# input variables
cost_of_ice_bag=1.25
profit_margin=.2
number_of_bags=500

# Template for output message
output_template="""If a grocery store sells ice bags at $ {} per bags,with then
the total profit it makes by selling {} ice bags is $ {}."""
print(output_template)
# Out:
# If a grocery store sells ice bags at $ {} per bags,with then
# the total profit it makes by selling {} ice bags is $ {}.

# %%
# inserting values into the string
total_profit = cost_of_ice_bag*profit_margin*number_of_bags
output_message=output_template.format(cost_of_ice_bag,profit_margin*100,number_of_bags,total_profit)

# %%
print(output_message)
# Out:
# If a grocery store sells ice bags at $ 1.25 per bags,with then
# the total profit it makes by selling 20.0 ice bags is $ 500.
