# %%
# A two-dimensional data structures with columns of potentially different types of dataframe.
import pandas as pd
import numpy as np

# %%
dict1 = {
    "name":['harry','rohan','dipesh','nikhil'],
    "marks":[20,30,50,35],
    "city":['rampur','tokyo','delhi','kathmandu']
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks       city
# 0   harry     20     rampur
# 1   rohan     30      tokyo
# 2  dipesh     50      delhi
# 3  nikhil     35  kathmandu

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index_false.csv',index=False)
